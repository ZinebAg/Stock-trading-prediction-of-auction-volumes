# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline 
import numpy as np
import matplotlib.animation as animation
import sys
import math
import seaborn as sns
import datetime
import random
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse
from statsmodels.tsa.stattools import adfuller, kpss
from sklearn.metrics import mean_squared_error
from sklearn.impute import KNNImputer

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.cluster import KMeans, DBSCAN
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

import sys

import re

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import scale
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_validate


random.seed(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#train data to run the model

y=pd.read_csv("/content/drive/MyDrive/Master Semester Project/data/output_training_IxKGwDV.csv")
y=y.target

# %%
#reading the dataframes with the different imputings
data_mean_no_constraint=pd.read_csv("/content/drive/MyDrive/Master Semester Project/data/data_mean_no_constraint.csv.gz", compression='gzip')
data_mean_constraint=pd.read_csv("/content/drive/MyDrive/Master Semester Project/data/data_mean_constraint.csv.gz", compression='gzip')
data_median_no_constraint=pd.read_csv("/content/drive/MyDrive/Master Semester Project/data/data_median_no_constraint.csv.gz", compression='gzip')
data_bfill=pd.read_csv("/content/drive/MyDrive/Master Semester Project/data/data_bfill.csv.gz", compression='gzip')
data_ffill=pd.read_csv("/content/drive/MyDrive/Master Semester Project/data/data_ffill.csv.gz", compression='gzip')
data_RF_KNN = pd.read_csv("/content/drive/MyDrive/Master Semester Project/data/data_RF_KNN_2.csv.gz", compression='gzip')

# %%
data_mean_constraint=pd.read_csv("/content/drive/MyDrive/Master Semester Project/data/data_mean_constraint.csv.gz", compression='gzip')
test_data_mean_constraint=pd.read_csv("/content/drive/MyDrive/Master Semester Project/data/test_mean_constraint.csv.gz", compression='gzip')

# %%
#_mean_contraint
model_1 = LinearRegression()
model_1.fit(data_mean_constraint, y)

test_predict_meanconstraint_LinearRegression = model_1.predict(test_data_mean_constraint)

MeanConstraint_LinearRegression=submission_file_template.copy()
MeanConstraint_LinearRegression.target=test_predict_meanconstraint_LinearRegression

MeanConstraint_LinearRegression=MeanConstraint_LinearRegression.set_index('ID')
MeanConstraint_LinearRegression.to_csv("/content/drive/MyDrive/Master Semester Project/notebooks/Week6/submissions/MeanConstraint_LinearRegression.csv")

# %%
# reading the test models
test_data_mean_no_constraint=pd.read_csv("/content/drive/MyDrive/Master Semester Project/data/test_mean_no_constraint.csv.gz", compression='gzip')
test_data_mean_constraint=pd.read_csv("/content/drive/MyDrive/Master Semester Project/data/test_mean_constraint.csv.gz", compression='gzip')
test_data_median_no_constraint=pd.read_csv("/content/drive/MyDrive/Master Semester Project/data/test_median_no_constraint.csv.gz", compression='gzip')
test_data_bfill=pd.read_csv("/content/drive/MyDrive/Master Semester Project/data/test_bfill.csv.gz", compression='gzip')
test_data_ffill=pd.read_csv("/content/drive/MyDrive/Master Semester Project/data/test_ffill.csv.gz", compression='gzip')
test_data_RF_KNN = pd.read_csv("/content/drive/MyDrive/Master Semester Project/data/test_RF_KNN_2.csv.gz", compression='gzip')

# %%
submission_file_template= pd.read_csv("/content/drive/MyDrive/Master Semester Project/notebooks/Week6/submission_csv_file_random_example.csv")

# %% [markdown]
# # linear regression with crossvalidation

# %%
print("Linear regression")

#_RFKNN
model_1 = LinearRegression()
model_1.fit(data_RF_KNN, y)
test_predict_RFKNN_LinearRegression = model_1.predict(test_data_RF_KNN)
RFKNN_LinearRegression=submission_file_template.copy()
RFKNN_LinearRegression=RFKNN_LinearRegression.set_index('ID')
RFKNN_LinearRegression.to_csv("/content/drive/MyDrive/Master Semester Project/notebooks/Week6/submissions/RFKNN_LinearRegression.csv")


#_mean_no_constraint
model_1 = LinearRegression()
model_1.fit(data_mean_no_constraint, y)

test_predict_meannoconstraint_LinearRegression = model_1.predict(test_data_mean_no_constraint)

MeanNoConstraint_LinearRegression=submission_file_template.copy()
MeanNoConstraint_LinearRegression.target=test_predict_meannoconstraint_LinearRegression

MeanNoConstraint_LinearRegression=MeanNoConstraint_LinearRegression.set_index('ID')
MeanNoConstraint_LinearRegression.to_csv("/content/drive/MyDrive/Master Semester Project/notebooks/Week6/submissions/MeanNoConstraint_LinearRegression.csv")


#_mean_contraint
model_1 = LinearRegression()
model_1.fit(data_mean_constraint, y)

test_predict_meanconstraint_LinearRegression = model_1.predict(test_data_mean_constraint)

MeanConstraint_LinearRegression=submission_file_template.copy()
MeanConstraint_LinearRegression.target=test_predict_meanconstraint_LinearRegression

MeanConstraint_LinearRegression=MeanConstraint_LinearRegression.set_index('ID')
MeanConstraint_LinearRegression.to_csv("/content/drive/MyDrive/Master Semester Project/notebooks/Week6/submissions/MeanConstraint_LinearRegression.csv")


#_median_no_constraint
model_1 = LinearRegression()
model_1.fit(data_median_no_constraint, y)

test_predict_mediannoconstraint_LinearRegression = model_1.predict(test_data_median_no_constraint)

MedianNoConstraint_LinearRegression=submission_file_template.copy()
MedianNoConstraint_LinearRegression.target=test_predict_mediannoconstraint_LinearRegression

MedianNoConstraint_LinearRegression=MedianNoConstraint_LinearRegression.set_index('ID')
MedianNoConstraint_LinearRegression.to_csv("/content/drive/MyDrive/Master Semester Project/notebooks/Week6/submissions/MedianNoConstraint_LinearRegression.csv")


#_bfill
model_1 = LinearRegression()
model_1.fit(data_bfill, y)

test_predict_bfill_LinearRegression = model_1.predict(test_data_bfill.fillna(0))

bfill_LinearRegression=submission_file_template.copy()
bfill_LinearRegression.target=test_predict_bfill_LinearRegression

bfill_LinearRegression=bfill_LinearRegression.set_index('ID')
bfill_LinearRegression.to_csv("/content/drive/MyDrive/Master Semester Project/notebooks/Week6/submissions/bfill_LinearRegression.csv")



# ffill
model_1 = LinearRegression()
model_1.fit(data_ffill, y)

test_predict_ffill_LinearRegression = model_1.predict(test_data_ffill)

ffill_LinearRegression=submission_file_template.copy()
ffill_LinearRegression.target=test_predict_ffill_LinearRegression

ffill_LinearRegression=ffill_LinearRegression.set_index('ID')
ffill_LinearRegression.to_csv("/content/drive/MyDrive/Master Semester Project/notebooks/Week6/submissions/ffill_LinearRegression.csv")

# %% [markdown]
# # ridge linear regression

# %%
# print("ridge Linear regression")

# #use k-fold CV to evaluate model

# #_RFKNN


# model_2 =RidgeCV(alphas=np.arange(0.5, 1, 0.01), cv=cv, scoring=( 'neg_mean_squared_error'))


# model_2.fit(data_RF_KNN, y)
# # summarize chosen configuration
# print('alpha: %f' % model_2.alpha_)
# alpha_RF_KNN=model_2.alpha_



# # #_KNN

# # model_2 =RidgeCV(alphas=np.arange(0.5, 1, 0.01), cv=cv, scoring=( 'neg_mean_squared_error'))


# # model_2.fit(data_KNN, y)
# # # summarize chosen configuration
# # print('alpha: %f' % model_2.alpha_)
# # alpha_KNN=model_2.alpha_



# #_mean_no_constraint


# model_2 =RidgeCV(alphas=np.arange(0.5, 1, 0.01), cv=cv, scoring=( 'neg_mean_squared_error'))


# model_2.fit(data_mean_no_constraint, y)
# # summarize chosen configuration
# print('alpha: %f' % model_2.alpha_)
# alpha_mean_no_constraint=model_2.alpha_



# #_mean_contraint


# model_2 =RidgeCV(alphas=np.arange(0.5, 1, 0.01), cv=cv, scoring=( 'neg_mean_squared_error'))


# model_2.fit(data_mean_constraint, y)
# # summarize chosen configuration
# print('alpha: %f' % model_2.alpha_)
# alpha_mean_contraint=model_2.alpha_



# #_median_no_constraint


# model_2 =RidgeCV(alphas=np.arange(0.5, 1, 0.01), cv=cv, scoring=( 'neg_mean_squared_error'))


# model_2.fit(data_median_no_constraint, y)
# # summarize chosen configuration
# print('alpha: %f' % model_2.alpha_)
# alpha_median_no_constraint=model_2.alpha_




# #_bfill


# model_2 =RidgeCV(alphas=np.arange(0.5, 1, 0.01), cv=cv, scoring=( 'neg_mean_squared_error'))


# model_2.fit(data_bfill, y)
# # summarize chosen configuration
# print('alpha: %f' % model_2.alpha_)
# alpha_bfill=model_2.alpha_



# #_ffill

# model_2 =RidgeCV(alphas=np.arange(0.5, 1, 0.01), cv=cv, scoring=( 'neg_mean_squared_error'))


# model_2.fit(data_ffill, y)
# # summarize chosen configuration
# print('alpha: %f' % model_2.alpha_)
# alpha_ffill=model_2.alpha_
# Out:
# ridge Linear regression
# alpha: 0.990000
# alpha: 0.500000
# alpha: 0.990000
# alpha: 0.500000
# alpha: 0.990000
# alpha: 0.990000

# %%
alpha_RF_KNN= 0.99
alpha_mean_no_constraint = 0.5
alpha_mean_contraint = 0.99
alpha_median_no_constraint = 0.5
alpha_bfill=0.99
alpha_ffill= 0.99

# %%
print("Ridge Linear regression")

#_RFKNN
model_1 = Ridge(alpha_RF_KNN)
model_1.fit(data_RF_KNN, y)
test_predict_RFKNN_RidgeLinearRegression = model_1.predict(test_data_RF_KNN)
RFKNN_RidgeLinearRegression=submission_file_template.copy()
RFKNN_RidgeLinearRegression=RFKNN_RidgeLinearRegression.set_index('ID')
RFKNN_RidgeLinearRegression.to_csv("/content/drive/MyDrive/Master Semester Project/notebooks/Week6/submissions/RFKNN_RidgeLinearRegression.csv")


#_mean_no_constraint
model_1 = Ridge(alpha_mean_no_constraint)
model_1.fit(data_mean_no_constraint, y)

test_predict_meannoconstraint_RidgeLinearRegression = model_1.predict(test_data_mean_no_constraint)

MeanNoConstraint_RidgeLinearRegression=submission_file_template.copy()
MeanNoConstraint_RidgeLinearRegression.target=test_predict_meannoconstraint_RidgeLinearRegression

MeanNoConstraint_RidgeLinearRegression=MeanNoConstraint_RidgeLinearRegression.set_index('ID')
MeanNoConstraint_RidgeLinearRegression.to_csv("/content/drive/MyDrive/Master Semester Project/notebooks/Week6/submissions/MeanNoConstraint_RidgeLinearRegression.csv")


#_mean_contraint
model_1 = Ridge(alpha_mean_contraint)
model_1.fit(data_mean_constraint, y)

test_predict_meanconstraint_RidgeLinearRegression = model_1.predict(test_data_mean_constraint)

MeanConstraint_RidgeLinearRegression=submission_file_template.copy()
MeanConstraint_RidgeLinearRegression.target=test_predict_meanconstraint_RidgeLinearRegression

MeanConstraint_RidgeLinearRegression=MeanConstraint_RidgeLinearRegression.set_index('ID')
MeanConstraint_RidgeLinearRegression.to_csv("/content/drive/MyDrive/Master Semester Project/notebooks/Week6/submissions/MeanConstraint_RidgeLinearRegression.csv")


#_median_no_constraint
model_1 = Ridge(alpha_median_no_constraint)
model_1.fit(data_median_no_constraint, y)

test_predict_mediannoconstraint_RidgeLinearRegression = model_1.predict(test_data_median_no_constraint)

MedianNoConstraint_RidgeLinearRegression=submission_file_template.copy()
MedianNoConstraint_RidgeLinearRegression.target=test_predict_mediannoconstraint_RidgeLinearRegression

MedianNoConstraint_RidgeLinearRegression=MedianNoConstraint_RidgeLinearRegression.set_index('ID')
MedianNoConstraint_RidgeLinearRegression.to_csv("/content/drive/MyDrive/Master Semester Project/notebooks/Week6/submissions/MedianNoConstraint_RidgeLinearRegression.csv")


#_bfill
model_1 = Ridge(alpha_bfill)
model_1.fit(data_bfill, y)

test_predict_bfill_RidgeLinearRegression = model_1.predict(test_data_bfill.fillna(0))

bfill_RidgeLinearRegression=submission_file_template.copy()
bfill_RidgeLinearRegression.target=test_predict_bfill_RidgeLinearRegression

bfill_RidgeLinearRegression=bfill_RidgeLinearRegression.set_index('ID')
bfill_RidgeLinearRegression.to_csv("/content/drive/MyDrive/Master Semester Project/notebooks/Week6/submissions/bfill_RidgeLinearRegression.csv")



# ffill
model_1 = Ridge(alpha_ffill)
model_1.fit(data_ffill, y)

test_predict_ffill_RidgeLinearRegression = model_1.predict(test_data_ffill)

ffill_RidgeLinearRegression=submission_file_template.copy()
ffill_RidgeLinearRegression.target=test_predict_ffill_RidgeLinearRegression

ffill_RidgeLinearRegression=ffill_RidgeLinearRegression.set_index('ID')
ffill_RidgeLinearRegression.to_csv("/content/drive/MyDrive/Master Semester Project/notebooks/Week6/submissions/ffill_RidgeLinearRegression.csv")
# Out:
# Linear regression
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=8.01705e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=8.32162e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=6.96461e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T

# %% [markdown]
# # Lasso lin regression

# %%
alpha= 0.1

# %%
print("Lasso Linear regression")

#_RFKNN
model_1 = Lasso(alpha)
model_1.fit(data_RF_KNN, y)
test_predict_RFKNN_LassoLinearRegression = model_1.predict(test_data_RF_KNN)
RFKNN_LassoLinearRegression=submission_file_template.copy()
RFKNN_LassoLinearRegression=RFKNN_LassoLinearRegression.set_index('ID')
RFKNN_LassoLinearRegression.to_csv("/content/drive/MyDrive/Master Semester Project/notebooks/Week6/submissions/RFKNN_LassoLinearRegression.csv")


#_mean_no_constraint
model_1 = Lasso(alpha)
model_1.fit(data_mean_no_constraint, y)

test_predict_meannoconstraint_LassoLinearRegression = model_1.predict(test_data_mean_no_constraint)

MeanNoConstraint_LassoLinearRegression=submission_file_template.copy()
MeanNoConstraint_LassoLinearRegression.target=test_predict_meannoconstraint_LassoLinearRegression

MeanNoConstraint_LassoLinearRegression=MeanNoConstraint_LassoLinearRegression.set_index('ID')
MeanNoConstraint_LassoLinearRegression.to_csv("/content/drive/MyDrive/Master Semester Project/notebooks/Week6/submissions/MeanNoConstraint_LassoLinearRegression.csv")


#_mean_contraint
model_1 = Lasso(alpha)
model_1.fit(data_mean_constraint, y)

test_predict_meanconstraint_LassoLinearRegression = model_1.predict(test_data_mean_constraint)

MeanConstraint_LassoLinearRegression=submission_file_template.copy()
MeanConstraint_LassoLinearRegression.target=test_predict_meanconstraint_LassoLinearRegression

MeanConstraint_LassoLinearRegression=MeanConstraint_LassoLinearRegression.set_index('ID')
MeanConstraint_LassoLinearRegression.to_csv("/content/drive/MyDrive/Master Semester Project/notebooks/Week6/submissions/MeanConstraint_LassoLinearRegression.csv")


#_median_no_constraint
model_1 = Lasso(alpha)
model_1.fit(data_median_no_constraint, y)

test_predict_mediannoconstraint_LassoLinearRegression = model_1.predict(test_data_median_no_constraint)

MedianNoConstraint_LassoLinearRegression=submission_file_template.copy()
MedianNoConstraint_LassoLinearRegression.target=test_predict_mediannoconstraint_LassoLinearRegression

MedianNoConstraint_LassoLinearRegression=MedianNoConstraint_LassoLinearRegression.set_index('ID')
MedianNoConstraint_LassoLinearRegression.to_csv("/content/drive/MyDrive/Master Semester Project/notebooks/Week6/submissions/MedianNoConstraint_LassoLinearRegression.csv")


#_bfill
model_1 = Lasso(alpha)
model_1.fit(data_bfill, y)

test_predict_bfill_LassoLinearRegression = model_1.predict(test_data_bfill.fillna(0))

bfill_LassoLinearRegression=submission_file_template.copy()
bfill_LassoLinearRegression.target=test_predict_bfill_LassoLinearRegression

bfill_LassoLinearRegression=bfill_LassoLinearRegression.set_index('ID')
bfill_LassoLinearRegression.to_csv("/content/drive/MyDrive/Master Semester Project/notebooks/Week6/submissions/bfill_LassoLinearRegression.csv")



# ffill
model_1 = Lasso(alpha)
model_1.fit(data_ffill, y)

test_predict_ffill_LassoLinearRegression = model_1.predict(test_data_ffill)

ffill_LassoLinearRegression=submission_file_template.copy()
ffill_LassoLinearRegression.target=test_predict_ffill_LassoLinearRegression

ffill_LassoLinearRegression=ffill_LassoLinearRegression.set_index('ID')
ffill_LassoLinearRegression.to_csv("/content/drive/MyDrive/Master Semester Project/notebooks/Week6/submissions/ffill_LassoLinearRegression.csv")
# Out:
# Lasso Linear regression
